# %% [markdown]
# ## Введение
#
# Суть моего проекта заключается на познание бодибилдинга и аниме. Был написан код и расписаны шаги. В шагах я расписал вопросы с вариантами ответов, но и функцию рандомайзера, чтобы варианты ответов перемешивались. Самое главное - работоспособность кода и редактирования вопроса с ответами!

# %%
def main():
  """Запускает викторину."""

  questions = [
    {
      "question": "Кто 7-ми кратный обладатель Mr. Olympia?",
      "options": ["Рони Коулмен", "Крис Бамстед", "Арнольд Шварценеггер", "Джек Кадлер"],
      "answer": "Арнольд Шварценеггер"
    },
    {
      "question": "Самый популятный анаболический препарат?",
      "options": ["Тренболон", "Туринобол", "Сустанон", "Дека"],
      "answer": "Тренболон"
    },
    {
      "question": "Какой персонаж из аниме Jujutsu Kaisen не обладает магией?",
      "options": ["Итадори Юдзи", "Годжо Сатору", "Рёмен Сукуна", "Тодзи Фусигуро"],
      "answer": "Тодзи Фусигуро"
    },
    {
      "question": "Какой персонаж из Jujutsu Kaisen сказал фразу: Какие девушки тебе нравятся?",
      "options": ["Мегуми Фусигуро", "Аой Тодо", "Мэи Мэи", "Утахиме"],
      "answer": "Аой Тодо"
    },
    {
      "question": "Какой персонаж из Blue Lock забил победный гол сборной Японии U20 ?",
      "options": ["Итоси Рин", "Шойи Баро", "Сейширо Наги", "Исаги Йоичи"],
      "answer": "Исаги Йоичи"
    }
  ]
  score = 0
  total_questions = len(questions)
  print("А вот ты и попался, пупсик! Добро пожаловать в викторину!")
  for i in range(total_questions):
    question_data = questions[i]
    question = question_data["question"]
    options = question_data["options"]
    answer = question_data["answer"]

    random.shuffle(options)

    print(f"\nВопрос {i+1}: {question}")
    for j, option in enumerate(options):
      print(f"{j+1}. {option}")

    user_answer = input("Ваш ответ (введите номер): ")

    if options[int(user_answer) - 1] == answer:
      print("Верно!")
      score += 1
    else:
      print(f"Неверно. Правильный ответ: {answer}")

  print(f"\nВаш результат: {score}/{total_questions}")

  if score == total_questions:
    print("Поздравляю! Ты избранный!")
  else:
    print("Ты не особо интересн мне!")

if __name__ == "__main__":
  main()

# %% [markdown]
# ## Вопросы с вариантами ответов:
#
# Были написаны списки вопросов с вариантами ответов, чтобы читатель смог понять какие вопросы будут в данном проекте.

# %%
  questions = [
    {
      "question": "Кто 7-ми кратный обладатель Mr. Olympia?",
      "options": ["Рони Коулмен", "Крис Бамстед", "Арнольд Шварценеггер", "Джек Кадлер"],
      "answer": "Арнольд Шварценеггер"
    },
    {
      "question": "Самый популятный анаболический препарат?",
      "options": ["Тренболон", "Туринобол", "Сустанон", "Дека"],
      "answer": "Тренболон"
    },
    {
      "question": "Какой персонаж из аниме Jujutsu Kaisen не обладает магией?",
      "options": ["Итадори Юдзи", "Годжо Сатору", "Рёмен Сукуна", "Тодзи Фусигуро"],
      "answer": "Тодзи Фусигуро"
    },
    {
      "question": "Какой персонаж из Jujutsu Kaisen сказал фразу: Какие девушки тебе нравятся?",
      "options": ["Мегуми Фусигуро", "Аой Тодо", "Мэи Мэи", "Утахиме"],
      "answer": "Аой Тодо"
    },
    {
      "question": "Какой персонаж из Blue Lock забил победный гол сборной Японии U20 ?",
      "options": ["Итоси Рин", "Шойи Баро", "Сейширо Наги", "Исаги Йоичи"],
      "answer": "Исаги Йоичи"
    }
  ]

# %% [markdown]
# ## Запуск викторины, рандомайзера, подчёта вариантов ответов и коментарий.

# %%
def main():
  """Запускает викторину."""
    ## тут вопросы
  score = 0
  total_questions = len(questions)
  print("А вот ты и попался, пупсик! Добро пожаловать в викторину!")
  for i in range(total_questions):
    question_data = questions[i]
    question = question_data["question"]
    options = question_data["options"]
    answer = question_data["answer"]

    random.shuffle(options)

    print(f"\nВопрос {i+1}: {question}")
    for j, option in enumerate(options):
      print(f"{j+1}. {option}")

    user_answer = input("Ваш ответ (введите номер): ")

    if options[int(user_answer) - 1] == answer:
      print("Верно!")
      score += 1
    else:
      print(f"Неверно. Правильный ответ: {answer}")

  print(f"\nВаш результат: {score}/{total_questions}")

  if score == total_questions:
    print("Поздравляю! Ты избранный!")
  else:
    print("Ты не особо интересн мне!")

if __name__ == "__main__":
  main()

# %% [markdown]
# ## Вывод
#
# Был написан код, для создания викторины. Чтоб проверить знания читателя в сфере бодибилдинга и аниме
